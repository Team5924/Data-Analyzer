# %%
from modules.data import raw_data
from packages.Analyzer.id import iD

# %%
id_pu = iD(raw_data)
id_num = 2

# %%
id_pu.lookup(id_num)
# Out:
#                              Auto                Score (Auto)          \
#    Team Match Attendance Mobility Docked Engaged          Top Mid Bot
# 1  5924    46        Yes      Yes     No      No            0   0   0
# 2   114    46        Yes      Yes     No      No            1   0   1
# 3  5419    46        Yes      Yes    Yes     Yes            0   0   0
# 4  4186    46        Yes       No     No      No            0   0   0
# 5  8169    46        Yes      Yes     No      No            1   0   0
# 6  6962    46        Yes       No    Yes     Yes            0   0   1
#
#   Score (Teleop)         Teleop                                               \
#              Top Mid Bot  Links Pieces Dropped       Status Defense Sabotage
# 1              0   0   2      5              0  Operational     N/A       No
# 2              2   2   2      5              0  Operational     N/A       No
# 3              0   3   4      5              0  Operational     N/A       No
# ...
