# %%
from modules.data import raw_data
from packages.Analyzer.team import Team

# %%
team_pu = Team(raw_data)
team = 5419

# %%
team_pu.overview(team)
# Out:
# 5419 Berkelium

# %%
team_pu.match(team)
# Out:
#                                  Auto                Score (Auto)          \
#          iD Match Attendance Mobility Docked Engaged          Top Mid Bot
# 1  Aidan L.    46        Yes      Yes    Yes     Yes            0   0   0
#
#   Score (Teleop)         Teleop                                               \
#              Top Mid Bot  Links Pieces Dropped       Status Defense Sabotage
# 1              0   3   4      5              0  Operational     N/A       No
#
#   Endgame                 Misc
#    Parked Docked Engaged Notes
# 1      No    Yes     Yes
