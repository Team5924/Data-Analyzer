# %% [markdown]
# ## Preamble

# %%
#### Imports
from files.data import raw_data
from api.Data import Data

# %%
data = Data(raw_data)
data.filter('pit')

# %% [markdown]
# ## Pit

# %%
data.display()
# Out:
#     iD  Team  Speed (ft/sec) Drive Train               Auto    Climb Time  \
# 0    5  9038            12.0        Tank  Place Game Pieces  > 15 seconds
# 1    5  9114             NaN        Tank   Docked & Engaged  < 15 seconds
# 2    5  9125            15.0        Tank  Place Game Pieces
# 3    5   581            14.0      Swerve   Docked & Engaged  < 15 seconds
# 4    5  <NA>             NaN        Tank  Place Game Pieces  < 15 seconds
# 5    5   299            14.0      Swerve  Place Game Pieces  < 15 seconds
# 6    5   115             NaN      Swerve  Place Game Pieces  < 15 seconds
# 7    5  8169             NaN        Tank  Place Game Pieces  < 15 seconds
# 8    5   841            20.0        Tank            No Auto  < 15 seconds
# 9    5  8840            14.0      Swerve   Docked & Engaged
# 10   5   649            16.0      Swerve   Docked & Engaged  < 15 seconds
# 11   5  8852            16.0        Tank  Place Game Pieces
# ...
